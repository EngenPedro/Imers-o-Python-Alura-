# %% [markdown]
# <a href="https://colab.research.google.com/github/EngenPedro/Imersao-Python-Alura/blob/main/Imers%C3%A3o_Python_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01 - Importação

# %% [markdown]
# Importando a Biblioteca Python

# %%
import pandas as pd

# %% [markdown]
# Abrindo o DataFramne utilizando a função read que faz a leitura do arquivo xlsx

# %%
df_principal = pd.read_excel('/content/Imersão Alura Tabela de Ações (1).xlsx', sheet_name='Principal')
df_principal.head(5)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia   Var. Sem  Var. Mês   Var. Ano   \
# 0  USIM5 2024-01-26         9.50       5.20     11.76       2.26       2.26
# 1  CMIN3 2024-01-26         6.82       2.40      2.40     -12.11     -12.11
# 2  PETR3        NaT        41.96       2.19      7.73       7.64       7.64
# 3  SUZB3 2024-01-26        52.91       2.04      2.14      -4.89      -4.89
# 4  CPFE3 2024-01-26        37.10       2.03      2.49      -3.66      -3.66
#
#    Var. 12M   Val. Mín  Val. Máx  ... Resultado.3  Variação Dia (%)  \
# 0      15.97      9.18      9.56  ...       Subiu            0.0520
# 1      50.56      6.66      6.86  ...       Subiu            0.0240
# 2      77.55     40.81     42.34  ...       Subiu            0.0219
# 3      18.85     51.89     53.17  ...       Subiu            0.0204
# 4      20.70     36.37     37.32  ...       Subiu            0.0203
#
#    Valor Inicial.4  Qnt. Ações.4  Variação R$.4 Resultado.4  Nome da Empresa  \
# ...

# %%
df_total_acoes = pd.read_excel('/content/Imersão Alura Tabela de Ações (1).xlsx', sheet_name='Total_de_acoes')
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %% [markdown]
# Exibir apenas as colunas especificas

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia ']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia
# 0   USIM5 2024-01-26         9.50       5.20
# 1   CMIN3 2024-01-26         6.82       2.40
# 2   PETR3        NaT        41.96       2.19
# 3   SUZB3 2024-01-26        52.91       2.04
# 4   CPFE3 2024-01-26        37.10       2.03
# ..    ...        ...          ...        ...
# 76  CRFB3 2024-01-26        10.71      -2.45
# 77  BHIA3 2024-01-26         8.70      -2.46
# 78  RENT3 2024-01-26        56.24      -3.63
# 79  CVCB3 2024-01-26         3.07      -4.36
# 80  GOLL4 2024-01-26         5.92      -8.07
#
# [81 rows x 4 columns]

# %% [markdown]
# Renomeando as colunas Última (R$) e Var. Dia

# %%
df_principal = df_principal.rename(columns={'Último (R$)' : 'Valor_Final', 'Var. Dia ' : 'Var_Dia_Pct'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3        NaT        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %% [markdown]
# Convertendo a coluna Var_pct porcentagem e criando uma nova coluna para armazenar a mesma

# %%
df_principal['Var_pct'] = df_principal['Var_Dia_Pct'] / 100
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct
# 0   USIM5 2024-01-26         9.50         5.20   0.0520
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240
# 2   PETR3        NaT        41.96         2.19   0.0219
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203
# ..    ...        ...          ...          ...      ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807
#
# [81 rows x 5 columns]

# %% [markdown]
# Calculando o Valor inicial das ações e criando uma nova coluna

# %%
df_principal['Valor_inicial'] = df_principal['Valor_Final'] / (df_principal['Var_pct'] +1 )
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3        NaT        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %% [markdown]
# Combinando os DataFrames df_principal e df_total_acoes com base nas colunas Ativo e Código

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156  CMIN3
# 2   PETR3        NaT        41.96         2.19   0.0219      41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# ...

# %% [markdown]
# Removendo a coluna codigo do DataFrame

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3        NaT        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# ...

# %%
df_principal['Variacao_R$'] = (df_principal['Valor_Final'] - df_principal['Valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3        NaT        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   Variacao_R$
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_R$
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# ...

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_R$
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# ...

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica' : 'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_R$
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# ...

# %%
df_ticker = pd.read_excel('/content/Imersão Alura Tabela de Ações (1).xlsx', sheet_name= 'Ticker')
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_R$'].apply(lambda x: "Subiu" if x > 0 else ("Desceu" if x < 0 else "Estável"))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_R$ Resultado
# 0     515117391   241889725.43     Subiu
# ...

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_R$ Resultado              Nome
# ...

# %%
df_chatgpt = pd.read_excel('/content/Imersão Alura Tabela de Ações (1).xlsx', sheet_name= 'Chat - GPT')
df_chatgpt
# Out:
#      Nome da Empresa                  Segmento  Idade em Anos
# 0           Usiminas                Siderurgia             60
# 1      CSN Mineração                 Mineração             17
# 2          Petrobras  Energia / Petróleo e Gás             68
# 3             Suzano          Papel e Celulose             97
# 4       CPFL Energia          Energia Elétrica             29
# ..               ...                       ...            ...
# 74  Carrefour Brasil                    Varejo             46
# 75       Casas Bahia                    Varejo             64
# 76          Localiza         Aluguel de Carros             48
# 77               CVC                   Turismo             49
# 78               GOL          Transporte Aéreo             21
#
# [79 rows x 3 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   PETR3        NaT        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_R$ Resultado              Nome  \
# ...

# %%
df_principal['Cat_idade'] = df_principal['Idade em Anos'].apply(lambda x: "Mais de 100" if x > 100 else ("Menos de 50" if x < 50 else "Entre 50 e 100"))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   PETR3        NaT        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_R$ Resultado              Nome  \
# ...

# %%
maior_variacao = df_principal['Variacao_R$'].max()

# Menor Variação
menor_variacao = df_principal['Variacao_R$'].min()

# Média
media_variacao = df_principal['Variacao_R$'].mean()

media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_R$'].mean()

# Média de Quem Desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_R$'].mean()

# %%
df_analises = pd.read_excel('/content/Imersão Alura Tabela de Ações (1).xlsx', sheet_name= 'Analises')
df_analises
# Out:
#                        Maior 4762926995.24809           Vale
# 0                      Menor   -1807432634.46       Localiza
# 1                      Média     165190210.48            NaN
# 2        Média de Quem Subiu     448164250.23            NaN
# 3       Média de Quem Desceu    -181109141.75            NaN
# 4                        NaN              NaN            NaN
# ..                       ...              ...            ...
# 60                       NaN              NaN            NaN
# 61  Análise por faixa etária      Variação R$  Qnt. Empresas
# 62       Entre 50 e 100 Anos   12036268360.98             31
# 63          Menos de 50 Anos    1058087374.40             46
# 64          Mais de 100 Anos     286051313.45              4
#
# [65 rows x 3 columns]

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_Pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3        NaT        41.96         2.19     0.02          41.06
# 3   PETR3        NaT        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 5   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 6   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 7   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 8   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 9   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 10  MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 11  ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# ...

# %% [markdown]
# Agrupar por segmento e somar a variação

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_R$'].sum().reset_index()
df_analise_segmento
# Out:
#                     Segmento    Variacao_R$
# 0                  Alimentos   407833683.09
# 1         Combustíveis e Gás   388705223.96
# 2    Conglomerado Financeiro   373853994.88
# 3           Construção Civil    37525872.38
# 4                   Educação    72295838.99
# 5      Energia / Agricultura   138800759.60
# 6   Energia / Petróleo e Gás 11354552963.61
# 7           Energia Elétrica   682315640.01
# 8     Investimentos Diversos    42238249.54
# 9                  Logística   233902674.79
# 10                 Mineração  4940442965.55
# 11             Moda / Varejo    41021792.09
# 12          Papel e Celulose   722946282.71
# 13                   Química    69054317.64
# 14                     Saúde   453917907.01
# 15      Serviços Financeiros  3784169702.16
# 16          Shopping Centers   117732680.08
# 17                Siderurgia   489935930.93
# 18                Tecnologia    15598886.65
# 19          Telecomunicações   292938114.42
# ...

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_R$'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_R$
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 24962422694.88

# %%
import plotly.express as px

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='varicao_rs', text='varicao_rs', title='Variação em Reais por Resultado')
fig.update_traces(texttemplate='R$ %{text:,.2f}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_R$'].sum().reset_index()
df_analise_segmento

# %% [markdown]
# # Utilizando o Copilot para melhorar o Grafico de Pizza adicionando porcentagem e colocando as categorias em ordem crescente com base no percentual

# %% [markdown]
# ![cop.png](data:image/png;base64,...)

# %%
fig = px.pie(df_analise_segmento, names='Segmento', values='Variacao_R$', title='Variação Reais por Segmento')
fig.show()

# Adicionando rótulos de porcentagem
fig.update_traces(textinfo='percent+label')

# Ordenando os segmentos
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=[{"values": [sorted(fig.data[0]['values'])],
                           "labels": [sorted(fig.data[0]['labels'])]}],
                    label="Ordenar",
                    method="restyle"
                ),
                dict(
                    args=[{"values": [fig.data[0]['values']],
                           "labels": [fig.data[0]['labels']]}],
                    label="Desordenar",
                    method="restyle"
                )
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.1,
            yanchor="top"
        ),
    ]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_analise_cat_idade = df_principal.groupby('Cat_idade')['Variacao_R$'].sum().reset_index()
df_analise_cat_idade
# Out:
#         Cat_idade    Variacao_R$
# 0  Entre 50 e 100 17279464045.72
# 1     Mais de 100   286051313.45
# 2     Menos de 50  1058087374.40

# %%
fig = px.bar(df_analise_cat_idade, x='Cat_idade', y='Variacao_R$', text='Variacao_R$', title='Variação em Reais por Categoria de Idade')
fig.update_traces(texttemplate='R$ %{text:,.2f}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
